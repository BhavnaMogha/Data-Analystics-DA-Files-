# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# multiple columns visualize
# perform aggregations in the graph
# Statistical analysis

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Numerical Columns
# - relplot
# - line plot
# - scatterplot

# %%
sns.relplot(x='total_bill',y='tip',data = df);

# %%
sns.relplot(x='total_bill',y='tip',hue='day',data = df);

# %%
sns.relplot(x='total_bill',y='tip',hue='day',size='sex',data = df);

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
sns.relplot(x='total_bill',y='tip',hue='day',size='sex',style='size',data = df);

# %%
sns.relplot(x='total_bill',y='tip',data = df,hue='day',size='sex',style='size',col='time',row='smoker');

# %%
sns.lineplot(x='total_bill',y='tip',data = df);

# %%
sns.scatterplot(x='total_bill',y='tip',data = df);

# %%
# Categorical Columns

# Catplot-----strip plot
# swarm plot
# barplot
# histplot
# count plot
# boxplot

# %%
sns.catplot(x='day',y='total_bill',hue='day',data = df); # strip plot

# %%
sns.catplot(x='day',y='total_bill',hue='sex',kind='swarm',data = df); # strip plot

# %%
d = df.groupby(['day'])['total_bill'].agg(['sum','mean','max','min']).reset_index()
d
# Out:
# C:\Users\cipl\AppData\Local\Temp\ipykernel_2416\2342053668.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   d = df.groupby(['day'])['total_bill'].agg(['sum','mean','max','min']).reset_index()
#     day      sum       mean    max   min
# 0  Thur  1096.33  17.682742  43.11  7.51
# 1   Fri   325.88  17.151579  40.17  5.75
# 2   Sat  1778.40  20.441379  50.81  3.07
# 3   Sun  1627.16  21.410000  48.17  7.25

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.barplot(x='day',y='total_bill',estimator='median',data=df,ci=None,palette='Set1');

# %%
sns.catplot(x='day',y='total_bill',estimator='median',kind='bar',data=df,ci=None,palette='Set1');

# %%
sns.histplot(x='size',data=df);

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
sns.countplot(x='sex',hue='sex',data=df);

# %%
sns.boxplot(y='tip',data=df);

# %%
sns.boxplot(x='day',y='tip',hue='sex',data=df);

# %%
sns.catplot(x='day',y='tip',hue='sex',kind='box',data=df);

# %%
# distplot

# %%
sns.distplot(df['tip']);

# %%
a = np.random.normal(size=100000)

# %%
sns.distplot(a);
